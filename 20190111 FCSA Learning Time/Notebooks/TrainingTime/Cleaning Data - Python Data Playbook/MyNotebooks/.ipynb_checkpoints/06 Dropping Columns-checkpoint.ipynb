# %%
import pandas as pd

# %%
df = pd.read_csv('../cleaning-data-python-data-playbook/artwork_sample.csv')

# %%
df.head()
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms          date not known
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# ...

# %%
df.drop(0).head(1)  # drop row by index value
# Out:
#      id accession_number         artist artistRole  artistId  \
# 1  1036           A00002  Blake, Robert     artist        38
#
#                                                title        dateText  \
# 1  Two Drawings of Frightened Figures, Probably f...  date not known
#
#               medium                           creditLine  year  \
# 1  Graphite on paper  Presented by Mrs John Richmond 1922   NaN
#
#    acquisitionYear             dimensions  width  height  depth units  \
# 1             1922  support: 311 x 213 mm    311     213    NaN    mm
#
#    inscription  thumbnailCopyright  \
# 1          NaN                 NaN
#
#                                         thumbnailUrl  \
# 1  http://www.tate.org.uk/art/images/work/A/A00/A...
#
#                                                  url
# 1  http://www.tate.org.uk/art/artworks/blake-two-...

# %%
df.drop('id', axis=1).head(1)  # axis = 1 indicates we are dropping column
# Out:
#   accession_number         artist artistRole  artistId  \
# 0           A00001  Blake, Robert     artist        38
#
#                                                title        dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...  date not known
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
#
#                             creditLine  year  acquisitionYear  \
# 0  Presented by Mrs John Richmond 1922   NaN             1922
#
#               dimensions  width  height  depth units  inscription  \
# 0  support: 394 x 419 mm    394     419    NaN    mm          NaN
#
#    thumbnailCopyright                                       thumbnailUrl  \
# 0                 NaN  http://www.tate.org.uk/art/images/work/A/A00/A...
#
#                                                  url
# 0  http://www.tate.org.uk/art/artworks/blake-a-fi...

# %%
df.drop(columns=['id','artistId']).head(1)  # drop multiple columns
# Out:
#   accession_number         artist artistRole  \
# 0           A00001  Blake, Robert     artist
#
#                                                title        dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...  date not known
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
#
#                             creditLine  year  acquisitionYear  \
# 0  Presented by Mrs John Richmond 1922   NaN             1922
#
#               dimensions  width  height  depth units  inscription  \
# 0  support: 394 x 419 mm    394     419    NaN    mm          NaN
#
#    thumbnailCopyright                                       thumbnailUrl  \
# 0                 NaN  http://www.tate.org.uk/art/images/work/A/A00/A...
#
#                                                  url
# 0  http://www.tate.org.uk/art/artworks/blake-a-fi...

# %%
df.drop(labels=[1,2,3]).head(3)  # drop rows based on index
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
# 5  1040           A00006  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
# 5      Ciampolo the Barrator Tormented by the Devils  1826–7, reprinted 1892
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# 4                            Line engraving on paper
# 5                            Line engraving on paper
#
#                                           creditLine    year  acquisitionYear  \
# 0                Presented by Mrs John Richmond 1922     NaN             1922
# ...

# %%
df.head(2)  # prior drop commands did not change the df (only returned new df)
# Out:
#      id accession_number         artist artistRole  artistId  \
# 0  1035           A00001  Blake, Robert     artist        38
# 1  1036           A00002  Blake, Robert     artist        38
#
#                                                title        dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...  date not known
# 1  Two Drawings of Frightened Figures, Probably f...  date not known
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# 1                                  Graphite on paper
#
#                             creditLine  year  acquisitionYear  \
# 0  Presented by Mrs John Richmond 1922   NaN             1922
# 1  Presented by Mrs John Richmond 1922   NaN             1922
#
#               dimensions  width  height  depth units  inscription  \
# 0  support: 394 x 419 mm    394     419    NaN    mm          NaN
# 1  support: 311 x 213 mm    311     213    NaN    mm          NaN
#
# ...

# %%
df.drop(columns=['id','artistRole'], inplace=True)  # use 'inplace' argument to permanently drop from dataset

# %%
df.head(2)
# Out:
#   accession_number         artist  artistId  \
# 0           A00001  Blake, Robert        38
# 1           A00002  Blake, Robert        38
#
#                                                title        dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...  date not known
# 1  Two Drawings of Frightened Figures, Probably f...  date not known
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# 1                                  Graphite on paper
#
#                             creditLine  year  acquisitionYear  \
# 0  Presented by Mrs John Richmond 1922   NaN             1922
# 1  Presented by Mrs John Richmond 1922   NaN             1922
#
#               dimensions  width  height  depth units  inscription  \
# 0  support: 394 x 419 mm    394     419    NaN    mm          NaN
# 1  support: 311 x 213 mm    311     213    NaN    mm          NaN
#
# ...

# %%
# use 'usecols' to define dataset columns when importing file
df = pd.read_csv('../cleaning-data-python-data-playbook/artwork_sample.csv', usecols=['id','artist','title','year'])
df.head(2)
# Out:
#      id         artist                                              title  \
# 0  1035  Blake, Robert  A Figure Bowing before a Seated Old Man with h...
# 1  1036  Blake, Robert  Two Drawings of Frightened Figures, Probably f...
#
#    year
# 0   NaN
# 1   NaN
