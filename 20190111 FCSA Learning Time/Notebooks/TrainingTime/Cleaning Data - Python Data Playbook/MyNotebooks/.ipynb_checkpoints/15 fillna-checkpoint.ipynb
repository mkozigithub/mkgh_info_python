# %%
import pandas as pd
df = pd.read_csv('../cleaning-data-python-data-playbook/artwork_data.csv', low_memory=False)
df.head(2)
# Out:
#      id accession_number         artist artistRole  artistId  \
# 0  1035           A00001  Blake, Robert     artist        38
# 1  1036           A00002  Blake, Robert     artist        38
#
#                                                title        dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...  date not known
# 1  Two Drawings of Frightened Figures, Probably f...  date not known
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# 1                                  Graphite on paper
#
#                             creditLine year  acquisitionYear  \
# 0  Presented by Mrs John Richmond 1922  NaN           1922.0
# 1  Presented by Mrs John Richmond 1922  NaN           1922.0
#
#               dimensions width height  depth units inscription  \
# 0  support: 394 x 419 mm   394    419    NaN    mm         NaN
# 1  support: 311 x 213 mm   311    213    NaN    mm         NaN
#
# ...

# %%
# want to change NaN in the depth column to 0
df.fillna(value={'depth': 0})  # fillna - supply a dictionary that maps column names to the value used to replace nan
# Out:
#            id accession_number  \
# 0        1035           A00001
# 1        1036           A00002
# 2        1037           A00003
# 3        1038           A00004
# 4        1039           A00005
# 5        1040           A00006
# 6        1041           A00007
# 7        1042           A00008
# 8        1043           A00009
# 9        1044           A00010
# 10       1045           A00011
# 11       1046           A00012
# 12       1047           A00013
# 13       1048           A00014
# 14       1049           A00015
# 15       1050           A00016
# 16       1051           A00017
# 17       1052           A00018
# 18       1053           A00019
# 19       1054           A00020
# 20       1055           A00021
# 21       1056           A00022
# 22       1057           A00023
# 23       1058           A00024
# 24       1059           A00025
# 25       1060           A00026
# 26       1061           A00027
# 27       1062           A00028
# 28       1063           A00029
# ...

# %%
pd.isnull(df['depth']).value_counts()
# Out:
# True     66687
# False     2514
# Name: depth, dtype: int64

# %%
df.fillna(value={'depth':0},inplace=True)  # use inplace=True to update source dataframe

# %%
pd.isnull(df['depth']).value_counts()
# Out:
# False    69201
# Name: depth, dtype: int64

# %%
df.head()
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms          date not known
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# ...
